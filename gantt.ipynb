# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

archivo = 'Marco-Logico.xlsx'
df = pd.read_excel(archivo)
df.head()
# Out:
#    Tabla 1                                         Unnamed: 1  \
# 0      NaN                                  Objetivo general
# 1      NaN  Analizar los factores relacionados con la viol...
# 2      NaN                                                NaN
# 3      NaN                                                NaN
#
#                                           Unnamed: 2  \
# 0                                      Meta general
# 1  Al término del proyecto haber identificado y d...
# 2                                                NaN
# 3                                                NaN
#
#                                           Unnamed: 3      Unnamed: 4  \
# 0                               Objetivo específicos    Temporalidad
# 1  Elaborar un diagnóstico social participativo s...      Semestre 1
# 2  Promover la creación de redes de mujeres en ST...      Semestre 2
# 3  Implementar estrategias de intervención instit...  Semestre 3 y 4
#
# ...

# %%
datos = [
    ["Identificación de participantes", "2026-06-01", "2026-07-01"],
    ["Diseño de herramientas", "2026-07-01", "2026-10-01"],
    ["Recolección de datos", "2026-06-01", "2027-06-01"],
    ["Análisis y elaboración del diagnóstico", "2027-01-15", "2027-05-01"],
    ["Talleres de liderazgo", "2027-06-01", "2027-08-01"],
    ["Creación de la red de mujeres en STEM", "2027-08-01", "2027-10-01"],
    ["Diseño de estrategias de incidencia", "2027-01-01", "2027-07-01"],
    ["Incidencia institucional", "2027-07-01", "2028-07-01"],
    ["Campaña de sensibilización", "2027-07-01", "2028-07-01"],
    ["Monitoreo y evaluación", "2026-06-01", "2028-07-01"],
    ["Difusión y divulgación", "2026-06-01", "2028-07-01"],
    ["Socialización de resultados", "2028-05-01", "2028-07-01"],
    ["Elaboración de informe final y sostenibilidad", "2028-05-01", "2028-07-01"]
]

# Diccionario de meses en español
meses_es = {'Jan': 'Ene', 'Feb': 'Feb', 'Mar': 'Mar', 'Apr': 'Abr', 'May': 'May', 'Jun': 'Jun', 'Jul': 'Jul', 'Aug': 'Ago', 'Sep': 'Sep', 'Oct': 'Oct', 'Nov': 'Nov', 'Dec': 'Dic'}

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import FixedLocator

df = pd.DataFrame(datos, columns=["Tarea", "Inicio", "Fin"])
df["Inicio"] = pd.to_datetime(df["Inicio"])
df["Fin"] = pd.to_datetime(df["Fin"])

fig, ax = plt.subplots(figsize=(14, 7))
for i, row in df.iterrows():
    ax.barh(row["Tarea"], (row["Fin"] - row["Inicio"]).days, left=row["Inicio"], color="skyblue", edgecolor="black")

ax.set_xlabel("Fecha")
ax.set_ylabel("Tarea")
ax.set_title("Plan de investigación - Cronograma Gantt (Junio 2026 - Junio 2028)")
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
plt.xticks(rotation=30)

# Traducir los meses a español en las etiquetas del eje x
labels = [item.get_text() for item in ax.get_xticklabels()]
locs = ax.get_xticks()
labels_es = [meses_es.get(label[:3], label[:3]) + label[3:] for label in labels]
ax.xaxis.set_major_locator(FixedLocator(locs))
ax.set_xticklabels(labels_es)

plt.tight_layout()
plt.savefig('gantt_chart.png', format='png', dpi=300, bbox_inches='tight')
plt.show()
plt.close(fig)
